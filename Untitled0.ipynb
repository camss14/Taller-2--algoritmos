# %%
iniciar
leer el número de equipos comprados n_comprados=50
leer el precio de compra por equipo precio_compra=150
leer la comision de compra %comision_compra= 3%
Calcular el monto total pagado por la compra= n_comprados
calcular la comision pagada al proveedor en la compra
leer el numero de equipos vendidos n_vendidos= 50
leer el precio de venta por equipo= precio_venta= 175
leer la comision de venta= % comision_venta= 3%
calcular el monto total recibido por la venta
calcular la ganancia neta
mostar el monto total pagado por la compra
mostrar la comision pagada en la compra
mostrar el monto total recibido por la por la venta
mostar la comision pagada en la venta
Mostrar la ganancia o perdida neta= ganancia_neta
finalizar

# %% [markdown]
# Algoritmo de programa de compra y venta de electronicos

# %% [markdown]
# pseudocodigo de programa de compra y venta de equipos electronicos

# %%
start
read n_purchased = 50
read purchase_price = 150
Read %purchase_commission = 3
calculate
total_purchase_amount = n_purchased * purchased_price
calculate
purchase_commission_amount = total_purchase_amount * %purchase_commission / 110
read n_sold = 50
read sale_price = 175
read %sale_commission = 3
calculate total_sale_amount = n_sold * price
calculate
sale_commission_amount = (total_sale_amount * %sale_commission / 100
calculate net_profit = total_sale_amount-sale_commission_amount) - (total_purchase_amount + purchase_commission_amount)
Display total_purchase_amount
Display purchase_commission_amount
Display sale_commission_amount
Display net_profit
End
